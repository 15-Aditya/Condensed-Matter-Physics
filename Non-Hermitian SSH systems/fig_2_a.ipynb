# %%
import matplotlib.pyplot as mpl
import numpy

num = 0.0
den = 0.0
eta = 0.0

gamma = numpy.linspace(-1.5, 1.5, num = 31, endpoint = True)
num = (1 - abs(gamma))**2
den = (1 + abs(gamma))**2
eta = num / den
mpl.plot(gamma, eta, 'o', markersize = '3', color = 'black')
mpl.show()
